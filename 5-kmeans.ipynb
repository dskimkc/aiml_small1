# %%
import pandas as pd, matplotlib.pyplot as plt
from sklearn.cluster import KMeans

points = pd.read_csv('ch1ex1.csv').values
model = KMeans(n_clusters=3).fit(points)
plt.scatter(points[:, 0], points[:, 1], c=model.labels_)
plt.scatter(*model.cluster_centers_.T, marker='X', s=200, color='red')
plt.show()
# Out:
# C:\Users\ANUSH S\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
